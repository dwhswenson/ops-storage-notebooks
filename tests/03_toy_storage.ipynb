# %%
from __future__ import print_function
# %matplotlib inline
import openpathsampling as paths
import openpathsampling.engines.toy as toys
import numpy as np

from openpathsampling.experimental.simstore import GeneralStorage
from openpathsampling.experimental.simstore import ClassInfoContainer, ClassInfo
from openpathsampling.experimental.simstore import universal_schema
from openpathsampling.experimental.simstore import SQLStorageBackend
import openpathsampling.experimental.simstore.serialization_helpers as serialization
from openpathsampling.experimental.simstore import tools

from openpathsampling.experimental.simstore.my_types import builtin_types

# %%
serialize_sim = lambda obj: {'uuid': serialization.get_uuid(obj), 'json': serialization.to_json_obj(obj)}
deserialize_sim = serialization.from_json_obj
serialize_data = serialization.to_dict_with_uuids
deserialize_data = lambda cls, data: cls.from_dict(serialization.from_dict_with)

# %%
from openpathsampling.netcdfplus import StorableObject
default_class_info = ClassInfo(table='simulation_objects',
                               cls=StorableObject,
                               serializer=serialize_sim,
                               deserializer=deserialize_sim)

# %%
backend = SQLStorageBackend(":memory:", mode='w')
storage = GeneralStorage(backend=backend,
                         schema={},
                         class_info=ClassInfoContainer(default_info=default_class_info))

# %%
backend.metadata.tables
# Out:
# FacadeDict({'schema': Table('schema', MetaData(), Column('table', String(), table=<schema>), Column('schema', String(), table=<schema>), schema=None), 'metadata': Table('metadata', MetaData(), Column('key', String(), table=<metadata>), Column('value', String(), table=<metadata>), schema=None), 'uuid': Table('uuid', MetaData(), Column('uuid', String(), table=<uuid>), Column('table', Integer(), table=<uuid>), Column('row', Integer(), table=<uuid>), schema=None), 'tables': Table('tables', MetaData(), Column('name', String(), table=<tables>), Column('idx', Integer(), table=<tables>), Column('module', String(), table=<tables>), Column('class_name', String(), table=<tables>), schema=None), 'sfr_result_types': Table('sfr_result_types', MetaData(), Column('uuid', String(), table=<sfr_result_types>), Column('result_type', String(), table=<sfr_result_types>), schema=None), 'tags': Table('tags', MetaData(), Column('name', String(), table=<tags>), Column('content', String(), table=<tags>), schema=None)})

# %%
schema = {
    'simulation_objects': [('json', 'json'), ('class_idx', 'int')]
}
storage.register_schema(schema, class_info_list=[])

# %%
storage.class_info
# Out:
# SerializationSchema(default_info=ClassInfo(table=simulation_objects, cls=<class 'openpathsampling.netcdfplus.base.StorableObject'>, lookup_result=<class 'openpathsampling.netcdfplus.base.StorableObject'>, find_uuids=<openpathsampling.experimental.simstore.serialization_helpers.SchemaFindUUIDs object at 0x16f649f10>), class_info_list=[ClassInfo(table=simulation_objects, cls=<class 'openpathsampling.netcdfplus.base.StorableObject'>, lookup_result=<class 'openpathsampling.netcdfplus.base.StorableObject'>, find_uuids=<openpathsampling.experimental.simstore.serialization_helpers.SchemaFindUUIDs object at 0x16f649f10>), ClassInfo(table=simulation_objects, cls=<class 'openpathsampling.netcdfplus.base.StorableObject'>, lookup_result=<class 'openpathsampling.netcdfplus.base.StorableObject'>, find_uuids=<openpathsampling.experimental.simstore.serialization_helpers.SchemaFindUUIDs object at 0x16f649f10>)])

# %% [markdown]
# ### Saving a toy engine
#
# First save the PES. Then save the whole engine. Make sure that the PES objects only show up once!

# %%
pes = (
    toys.OuterWalls([1.0, 1.0], [0.0, 0.0]) +
    toys.Gaussian(-0.7, [12.0, 12.0], [0.0, 0.4]) +
    toys.Gaussian(-0.7, [12.0, 12.0], [-0.5, -0.5]) +
    toys.Gaussian(-0.7, [12.0, 12.0], [0.5, -0.5])
)

# %%
storage.save(pes)

with backend.engine.connect() as conn:
    uuids = conn.execute(backend.metadata.tables['uuid'].select())
    sim_obj = conn.execute(backend.metadata.tables['simulation_objects'].select())
    
print(list(uuids))
    
for obj in sim_obj:
    print(obj)
# Out:
# [('84793823704981541439266122902907387932', 0, 1)]
# (1, '84793823704981541439266122902907387932', '{"pes2": "UUID(84793823704981541439266122902907387930)", "pes1": "UUID(84793823704981541439266122902907387928)", "__module__": "openpathsampling.engines.toy.pes", "__class__": "PES_Add"}', None)

# %%
topology=toys.Topology(
    n_spatial = 2,
    masses =[1.0, 1.0],
    pes = pes
)
integ = toys.LangevinBAOABIntegrator(dt=0.02, temperature=0.1, gamma=2.5)

options={
    'integ' : integ,
    'n_frames_max' : 5000,
    'n_steps_per_frame' : 1
}

engine = toys.Engine(
    options=options,
    topology=topology
)

# %%
storage.save(engine)

# %%
with backend.engine.connect() as conn:
    sim_obj = conn.execute(backend.metadata.tables['simulation_objects'].select())
        
for obj in sim_obj:
    print(obj)
# Out:
# (1, '84793823704981541439266122902907387932', '{"pes2": "UUID(84793823704981541439266122902907387930)", "pes1": "UUID(84793823704981541439266122902907387928)", "__module__": "openpathsampling.engines.toy.pes", "__class__": "PES_Add"}', None)
# (2, '84793823704981541439266122902907387940', '{"options": {"n_frames_max": 5000, "on_max_length": "fail", "on_nan": "fail", "retries_when_nan": 2, "retries_when_error": 0, "retries_when_max_lengt ... (118 characters truncated) ... rame": 1}, "topology": "UUID(84793823704981541439266122902907387934)", "__module__": "openpathsampling.engines.toy.engine", "__class__": "ToyEngine"}', None)

# %% [markdown]
# ### Storing a snapshot
#
# Snapshots need to separately register with storage. Here we'll do that manually.

# %%
template = toys.Snapshot(
    coordinates=np.array([[-0.5, -0.5]]), 
    velocities=np.array([[0.0,0.0]]),
    engine=engine
)

# %%
# this needs to be built by the snapshot itself, based on the engine descriptor
snapshot_schema = {'snapshot0': [('coordinates', 'ndarray.float64(1,2)'), ('velocities', 'ndarray.float64(1,2)'),
                                 ('engine', 'uuid')]}
snapshot_class_info = ClassInfo(table='snapshot0', cls=toys.ToySnapshot, serializer=None, deserializer=None)

# %%
storage.register_schema(snapshot_schema, [snapshot_class_info])

# %%
storage.class_info
# Out:
# SerializationSchema(default_info=ClassInfo(table=simulation_objects, cls=<class 'openpathsampling.netcdfplus.base.StorableObject'>, lookup_result=<class 'openpathsampling.netcdfplus.base.StorableObject'>, find_uuids=<openpathsampling.experimental.simstore.serialization_helpers.SchemaFindUUIDs object at 0x16f649f10>), class_info_list=[ClassInfo(table=simulation_objects, cls=<class 'openpathsampling.netcdfplus.base.StorableObject'>, lookup_result=<class 'openpathsampling.netcdfplus.base.StorableObject'>, find_uuids=<openpathsampling.experimental.simstore.serialization_helpers.SchemaFindUUIDs object at 0x16f649f10>), ClassInfo(table=simulation_objects, cls=<class 'openpathsampling.netcdfplus.base.StorableObject'>, lookup_result=<class 'openpathsampling.netcdfplus.base.StorableObject'>, find_uuids=<openpathsampling.experimental.simstore.serialization_helpers.SchemaFindUUIDs object at 0x16f649f10>), ClassInfo(table=snapshot0, cls=<class 'openpathsampling.engines.toy.snapshot.ToySnapshot'>, lookup_result=<class 'openpathsampling.engines.toy.snapshot.ToySnapshot'>, find_uuids=<openpathsampling.experimental.simstore.serialization_helpers.SchemaFindUUIDs object at 0x16f68f010>)])

# %%
storage.save(template)

# %% [markdown]
# ### Storing a fresh snapshot/engine
#
# The previous only added the snapshot to the store, because the engine had been loaded above.

# %%
new_engine = toys.Engine(
    options=options,
    topology=topology
)

new_snapshot = toys.Snapshot(
    coordinates=np.array([[-0.5, -0.5]]), 
    velocities=np.array([[0.0,0.0]]),
    engine=new_engine
)

# note that topology/PES is still the same, so should not store

# %%
storage.save(new_snapshot)

# %% [markdown]
# ### Registering snapshot class from the features

# %%
from openpathsampling.experimental.storage.snapshots import schema_from_entries, schema_for_snapshot, snapshot_registration_info

# %%
new_snapshot.engine.descriptor
# Out:
# frozenset({('class', openpathsampling.engines.toy.snapshot.ToySnapshot),
#            ('n_atoms', 1),
#            ('n_spatial', 2)})

# %%
new_snapshot.__features__.lazy
# Out:
# []

# %%
schema_from_entries(new_snapshot.__features__.classes, new_snapshot.__features__.lazy)
# Out:
# {'snapshot': [('velocities', 'ndarray.float32({n_atoms},{n_spatial})'),
#   ('coordinates', 'ndarray.float32({n_atoms},{n_spatial})'),
#   ('engine', 'uuid')]}

# %%
schema_for_snapshot(new_snapshot)
# Out:
# {'snapshot': [('velocities', 'ndarray.float32({n_atoms},{n_spatial})'),
#   ('coordinates', 'ndarray.float32({n_atoms},{n_spatial})'),
#   ('engine', 'uuid')]}

# %%
snapshot_registration_info(new_snapshot, 0)
# Out:
# ({'snapshot0': [('velocities', 'ndarray.float32({n_atoms},{n_spatial})'),
#    ('coordinates', 'ndarray.float32({n_atoms},{n_spatial})'),
#    ('engine', 'uuid')]},
#  [ClassInfo(table=snapshot0, cls=<class 'openpathsampling.engines.toy.snapshot.ToySnapshot'>, lookup_result=('84793823704981541439266122902907387946', <class 'openpathsampling.engines.toy.snapshot.ToySnapshot'>), find_uuids=None)])
